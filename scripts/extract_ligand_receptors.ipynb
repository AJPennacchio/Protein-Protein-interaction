# %%
import pandas as pd

# %%
ligands = pd.read_excel("TCO_Parenchyma_Young final version.xlsx", sheet_name="Overlap_TCO_All_ParvsVesvsPla")
ligands["T: Majority protein IDs.1"].to_csv('ligands.txt', index=False, header=False)
# Out:
#   T: Majority protein IDs     PBS1     PBS2     PBS3     PBS4     PBS5  \
# 0                  P01864  18.6197  17.3549  15.7228  18.4069  15.8834
# 1                  P01867  18.7888  16.5691  17.0233  18.5060  17.5099
# 2                  Q921I1  15.6030  17.7994  16.2957  17.9910  16.4253
# 3                  O08677  18.2020  17.5841  17.0448  17.5201  16.2059
# 4                  P01837  17.9834  18.5367  16.3546  18.0251  17.5597
#
#       TCO1     TCO2     TCO3     TCO4  ...  N: Q-value  N: Score  \
# 0  22.3098  25.3737  25.5218  24.1538  ...         0.0    44.818
# 1  22.4717  25.6908  25.6830  25.4961  ...         0.0   144.610
# 2  24.5319  26.3656  26.2341  22.4951  ...         0.0   323.310
# 3  19.6291  21.1754  20.7842  20.7140  ...         0.0    27.696
# 4  24.8552  28.8548  28.0717  22.9976  ...         0.0   136.070
#
#    N: Intensity  N: MS/MS count             T: Protein IDs  \
# 0     165630000              29       P01864;P01863;P01865
# ...

# %%
receptors = pd.read_excel("23.10.27 NHS-biotin receptor_Young.xlsx", sheet_name="NHS hits")
receptors.head()
# Out:
#   T: Majority protein IDs  LFQ intensity 04  LFQ intensity 05  \
# 0                     NaN               NaN               NaN
# 1                  Q64449           20.0574           18.5292
# 2                  Q9R118           18.9078           19.3801
# 3                  Q63844           20.6192           18.9120
# 4                  O08532           20.1306           18.5411
#
#    LFQ intensity 06  LFQ intensity 07  LFQ intensity 09  LFQ intensity 10  \
# 0               NaN               NaN               NaN               NaN
# 1           19.3185           18.9056           31.7241           30.9302
# 2           20.1262           19.1616           32.5492           29.9280
# 3           18.5089           18.1982           32.5424           30.7022
# 4           18.8385           19.4758           30.5121           29.9484
#
#    LFQ intensity 11  LFQ intensity 12  Unnamed: 9  ...  Unnamed: 20  \
# 0               NaN               NaN         NaN  ...          NaN
# ...

# %%
receptors["T: Majority protein IDs.1"].to_csv("receptors.txt", header=False, index=False)

# %%
receptors["T: Majority protein IDs.1"].nunique()
# Out:
# 2670
